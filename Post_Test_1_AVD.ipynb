# %% [markdown]
# # **DATASET MARKETING CAMPAIGN DATA**

# %%
import pandas as pd

# %%
file = "/content/drive/MyDrive/PRAKTIKUM AVD KE 1/Post test 1/marketing_campaign_data_messy.csv"
df = pd.read_csv(file)

df.head(100)
# Out:
#     Campaign_ID              Campaign_Name           Start_Date    End_Date  \
# 0      CMP-00001       Q4_Summer_CMP-00001  2023-11-24 00:00:00  2023-12-13
# 1      CMP-00002       Q1_Launch_CMP-00002  2023-05-06 00:00:00  2023-05-12
# 2      CMP-00003       Q3_Winter_CMP-00003  2023-12-13 00:00:00  2023-12-20
# 3      CMP-00004  Q1_BlackFriday_CMP-00004           2023-10-30  2023-11-03
# 4      CMP-00005       Q2_Winter_CMP-00005  2023-04-22 00:00:00  2023-04-23
# ..           ...                       ...                  ...         ...
# 95     CMP-00096       Q1_Winter_CMP-00096  2023-06-10 00:00:00  2023-06-28
# 96     CMP-00097       Q3_Summer_CMP-00097  2023-12-10 00:00:00  2023-12-21
# 97     CMP-00098       Q4_Summer_CMP-00098           07/02/2023  2023-02-26
# 98     CMP-00099  Q4_BlackFriday_CMP-00099  2023-11-15 00:00:00  2023-12-11
# 99     CMP-00100  Q2_BlackFriday_CMP-00100  2023-02-07 00:00:00  2023-02-18
#
# ...

# %% [markdown]
# # **BUSINESS UNDERSTANDING**

# %% [markdown]
# ## **Business Objective**

# %% [markdown]
# Dataset ini membahas tentang Analisis Efektivitas Data Kampanye Pemasaran berdasarkan data pelanggan yang di mana kita disini memahami karakteristik pelanggan dan menganalisis keberhasilan promosi dari kampanya marketing.Dataset Ini gunanya membantu perusahaan dalam meningkatkan efektivitas kampanye pemasaran melalui pemahaman terhadap karakteristik dan perilaku pelanggan.Perusahaan mengalami sebuah tantangan dimana tidak semua pelanggan memberikan respon yang terhadap promosi yang diberikan pada pemasaran kampanya tersebut, sehingga banyak biaya pemasaran yang terbuang tanpa menghasilkan hasil yang optimal.jadi dengan analisis ini tujuan nya ialah agar strategi pemasaran lebih tepat sasaran,biaya promosi lebih efisien,meningkatkan keberhasilan kampanye,serta berdampak pada peningkatan respon pelanggan.

# %% [markdown]
# ## **Asses Situation**

# %% [markdown]
# Dalam dataset ini hasil data kampanye pemasarannya masih berantakan,belum di olah dan belum bersih.Dataset ini mewakili respon pelanggan, perilaku pembelian, dan hasil keterlibatan kampanye yang dikumpulkan dari sebuah inisiatif pemasaran.Dalam dataset ini masih ada beberapa nilai yang hilang,format yang tidak konsisten,Variabel kategorikal yang perlu dienkode,duplikat dan kolom teks yang tidak terstruktur.

# %% [markdown]
# ## **Analytics Goals**

# %% [markdown]
# Analytics Goals nya ialah Mengidentifikasi Karakteristik pelanggan yang merespon dengan loyalitas pada kampanye yang di adakan,menemukan faktor keberhasilan promosi marketing kampanye dan membantu perusahaan dalam melakukan segmentasi pelanggan agar strategi pemasaran menjadi lebih efektif dan efisien.

# %% [markdown]
# ## **Project Plan**

# %% [markdown]
# Untuk mencapai tujuan tersebut rencana yang akan di lakukan adalah mula dengan memproses data cleaning untuk menangani missing value, menghapus duplikasi, dan memperbaiki format data.Selanjutnya dilakukan exploratory data analysis (EDA) untuk menemukan pola hubungan antara karakteristik pelanggan dengan respons terhadap kampanye. lalu selanjutnya,melakukan segmentasi pada pelanggan untuk membedakan antara pelanggan yang responsif dan tidak responsif terhadap promosi. Hasil dari analisis ini diharapkan bisa memberikan insight dan rekomendasi strategi marketing pada perusahaan agar perusahaan kedepannya bisa melakukan strategi marketing yang lebih efektif dan efisien.
